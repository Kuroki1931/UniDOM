# %%
import io
import cv2
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D

# %%
import cv2
import numpy as np

# Read image
image = cv2.imread('/root/ExPCP/policy/pbm/output/Rope/Rope-v1/2023-05-03 10:26:05.843822/0.5_init.png')

# Convert image to HSV color space
hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# Define pink color range in HSV
lower_pink = np.array([140, 50, 50])
upper_pink = np.array([170, 255, 255])

# Create a mask for pink color
mask = cv2.inRange(hsv, lower_pink, upper_pink)

# # Apply morphological operations (erosion and dilation) to reduce noise and separate objects
# kernel = np.ones((3, 3), np.uint8)
# mask = cv2.erode(mask, kernel, iterations=2)
# mask = cv2.dilate(mask, kernel, iterations=2)

# Find contours in the masked image
contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Count the number of contours
num_pink_objects = len(contours)
print('Number of separate pink objects:', num_pink_objects)

result = image.copy()
cv2.drawContours(result, contours, -1, (0, 255, 0), 2)

# Visualize the original image, masked image, and the result image with contours
cv2.imshow('Original Image', image)
cv2.imshow('Masked Image', mask)
cv2.imshow('Result Image with Contours', result)

# Wait for a keypress and close the windows
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of separate pink objects: 1

# %%
image = cv2.imread('/root/ExPCP/policy/pbm/output/Rope/Rope-v1/2023-05-03 10:26:05.843822/0.5_init.png')

# %%
import numpy as np
aaa = np.load('/root/ExPCP/policy/pbm/output/Rope/Rope-v39/2023-05-03 12:29:08.907094/action.npy')

# %%
import pickle
import matplotlib.pyplot as plt
with open('/home/robot_dev4/kuroki/UniDOM/ExPCP/policy/pbm/experts/Rope/Rope-v1/expert_0.0000_01:39:18.pickle', 'rb') as f: 
    data = pickle.load(f)

# %%
for i in data['plasticine_pc']:
    plt.scatter(i[:, 0], i[:, 2])

# %%
data
# Out:
# {'action': array([[1.08846834, 1.08932503, 0.98082274],
#         [1.05562342, 1.00834326, 0.95823032],
#         [0.99715689, 0.99022524, 1.01923632],
#         [0.97763019, 0.99971089, 0.92282584],
#         [1.02522485, 1.04936079, 1.08629155],
#         [1.05333674, 0.95676879, 1.0589677 ],
#         [1.07065   , 0.92268308, 0.94429285],
#         [1.02946881, 0.97918379, 1.05665372],
#         [1.01698714, 1.00479825, 0.9017201 ],
#         [1.0451289 , 1.00180568, 1.11980385],
#         [1.08461759, 0.98265039, 0.99803408],
#         [1.04026102, 1.00707691, 0.95816351]]),
#  'mu': 47.53198042323166,
#  'lam': 74.82920440979423,
#  'yield_stress': 10.021731215295528,
#  'rewards': array([  7.68329354,  15.05826092,  17.84787486,  19.55873177,
#          13.29500773,   5.53307758,   0.97274194,  -2.21122078,
#          -4.78253223,  -7.179624  ,  -9.3151708 , -11.17575595]),
#  'env_name': 'Rope-v1',
#  'plasticine_pc': array([[[0.50488135, 0.03575947, 0.50513817],
#          [0.50448832, 0.02118274, 0.50729471],
#          [0.49375872, 0.04458865, 0.52318314],
#          ...,
#          [0.48931662, 0.01334402, 0.52160482],
#          [0.49114085, 0.02567023, 0.4786111 ],
#          [0.45691514, 0.0379032 , 0.5216003 ]],
#
#         [[0.50701443, 0.03549905, 0.50499392],
#          [0.50712784, 0.02147908, 0.50705654],
#          [0.49343008, 0.0442585 , 0.52293518],
#          ...,
#          [0.48940485, 0.01346426, 0.52135473],
#          [0.49140003, 0.02571   , 0.47883693],
#          [0.45686586, 0.03786772, 0.52160787]],
#
#         [[0.51028028, 0.03482033, 0.50441117],
#          [0.51101022, 0.02282929, 0.50609772],
#          [0.49481633, 0.04329017, 0.52188553],
#          ...,
#          [0.49098333, 0.01425042, 0.52022191],
#          [0.49263708, 0.02596459, 0.47982909],
#          [0.45679267, 0.03780166, 0.52162422]],
#
#         ...,
#
#         [[0.51552434, 0.03485488, 0.50349978],
#          [0.51776468, 0.02546684, 0.50468935],
#          [0.49764061, 0.04315282, 0.52110882],
#          ...,
#          [0.49383529, 0.01568802, 0.51901093],
#          [0.49466836, 0.0265427 , 0.4806823 ],
#          [0.45780893, 0.03792481, 0.5215996 ]],
#
#         [[0.51484359, 0.03494796, 0.50350721],
#          [0.51715871, 0.02550794, 0.50470077],
#          [0.49728653, 0.04326948, 0.52126334],
#          ...,
#          [0.49374808, 0.01568912, 0.51905759],
#          [0.49442866, 0.02655428, 0.48056212],
#          [0.45777697, 0.03793368, 0.52162284]],
#
#         [[0.51418352, 0.03507837, 0.50351141],
#          [0.51652888, 0.02557924, 0.50472024],
#          [0.4969378 , 0.04333732, 0.52135985],
#          ...,
#          [0.4936264 , 0.01569097, 0.51911301],
#          [0.4941648 , 0.02656826, 0.48045798],
#          [0.45772998, 0.03792998, 0.52163931]]]),
#  'primitive_pc': array([[0.545     , 0.025     , 0.5       ],
#         [0.565     , 0.02501   , 0.50000981],
#         [0.585     , 0.02502   , 0.50001939],
#         [0.60494314, 0.0250299 , 0.50002939],
#         [0.62449574, 0.0250399 , 0.50003862],
#         [0.64449574, 0.0250499 , 0.50004862],
#         [0.66449574, 0.02505947, 0.50005862],
#         [0.68449574, 0.02506869, 0.50006806],
#         [0.70449574, 0.02507849, 0.50007806],
#         [0.72449574, 0.02508849, 0.50008708],
#         [0.74449574, 0.02509849, 0.50009708],
#         [0.76449574, 0.02510831, 0.50010706]])}

# %%
rope_state
# Out:
# array([[0.50997664, 0.03879384, 0.50368504],
#        [0.5117473 , 0.02685666, 0.50528342],
#        [0.49708852, 0.04585678, 0.52134318],
#        ...,
#        [0.49488252, 0.01705985, 0.51917652],
#        [0.49452207, 0.02836068, 0.47985514],
#        [0.45803829, 0.03825888, 0.52161857]])
